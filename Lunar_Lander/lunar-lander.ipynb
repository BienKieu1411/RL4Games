# %%
# !apt-get install -y swig
# !pip install box2d-py gymnasium[box2d]
# Out:
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 38 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (843 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 128663 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (0.0.4)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.3.1.post0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium[box2d]) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium[box2d]) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium[box2d]) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium[box2d]) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium[box2d]) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium[box2d]) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.0->gymnasium[box2d]) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.0->gymnasium[box2d]) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.0->gymnasium[box2d]) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.0->gymnasium[box2d]) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.0->gymnasium[box2d]) (2024.2.0)
# Downloading swig-4.3.1.post0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.5 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2351231 sha256=cceebb5a06cd5a84e573a0d7fccb133aecf761915fe2f1f07b1b6ea176c67c8a
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: swig, box2d-py
# Successfully installed box2d-py-2.3.5 swig-4.3.1.post0

# %%
# !pip install stable-baselines3
# !pip install gymnasium
# !pip install imageio
# !pip install pygame
# Out:
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.11/dist-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (0.29.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.20->stable-baselines3) (2.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.13->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.13->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.2.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->stable-baselines3) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.20->stable-baselines3) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.20->stable-baselines3) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.20->stable-baselines3) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.20->stable-baselines3) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 83.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 29.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.8 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 30.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.0->gymnasium) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.0->gymnasium) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.0->gymnasium) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.0->gymnasium) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.0->gymnasium) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.0->gymnasium) (2024.2.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (2.37.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from imageio) (1.26.4)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio) (11.2.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->imageio) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->imageio) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->imageio) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->imageio) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->imageio) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->imageio) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->imageio) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->imageio) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->imageio) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->imageio) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->imageio) (2024.2.0)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (2.6.1)

# %%
import os
import argparse
from pathlib import Path
import warnings
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from stable_baselines3.common.callbacks import CheckpointCallback, EvalCallback, StopTrainingOnRewardThreshold
from gymnasium.wrappers import RecordVideo  

os.environ["XDG_RUNTIME_DIR"] = "/tmp"
warnings.filterwarnings("ignore")

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)

def default_output_dir(save_dir):
    out_dir = Path(save_dir) / "lunarlander_ppo"
    ensure_dir(out_dir)
    return out_dir

def make_lunar_env(render_mode=None, seed=0):
    def _init():
        env = gym.make("LunarLander-v2", render_mode=render_mode)
        env.reset(seed=seed)
        return env
    return _init

def make_vec_envs(n_envs=1, seed=0):
    envs = DummyVecEnv([make_lunar_env(seed=i+seed) for i in range(n_envs)])
    envs = VecMonitor(envs)
    return envs

def parse_args():
    p = argparse.ArgumentParser()
    p.add_argument("--timesteps", type=int, default=10_000_000)
    p.add_argument("--save_dir", type=str, default="outputs")
    p.add_argument("--reward_threshold", type=float, default=250.0)
    p.add_argument("--render_video", action="store_true")
    return p.parse_args(args=["--render_video"])  

def main():
    args = parse_args()
    out_dir = default_output_dir(args.save_dir)
    log_dir = out_dir / "logs"
    ensure_dir(log_dir)

    train_env = make_vec_envs(1)
    eval_env = make_vec_envs(1, seed=42)

    model = PPO(
        "MlpPolicy",
        train_env,
        verbose=1,
        tensorboard_log=str(log_dir),
        device="cpu",
        n_steps=10000,     
        batch_size=512     
    )

    checkpoint_callback = CheckpointCallback(
        save_freq=100_000,
        save_path=str(out_dir / "checkpoints"),
        name_prefix="ppo_lunar"
    )

    stop_callback = StopTrainingOnRewardThreshold(
        reward_threshold=args.reward_threshold,
        verbose=1
    )

    eval_callback = EvalCallback(
        eval_env,
        callback_on_new_best=checkpoint_callback,
        best_model_save_path=str(out_dir / "best_model"),
        log_path=str(out_dir / "eval_logs"),
        eval_freq=100_000,
        n_eval_episodes=5,
        deterministic=True,
        render=False,
        callback_after_eval=stop_callback
    )

    model.learn(total_timesteps=args.timesteps, callback=[eval_callback])
    model.save(str(out_dir / "final_model.zip"))

    if args.render_video:
        video_path = out_dir / "video"
        ensure_dir(video_path)

        env = gym.make("LunarLander-v2", render_mode="rgb_array")
        env = RecordVideo(env, str(video_path), episode_trigger=lambda x: True)

        best_model_path = out_dir / "best_model" / "best_model.zip"
        model = PPO.load(str(best_model_path))

        obs, _ = env.reset(seed=0)
        done = False
        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, terminated, truncated, info = env.step(action)  
            done = terminated or truncated

        env.close()

if __name__ == "__main__":
    main()
# Out:
# 2025-08-30 11:19:20.295425: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1756552760.489321      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1756552760.544254      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using cpu device
# Logging to outputs/lunarlander_ppo/logs/PPO_1
# -----------------------------------
# | rollout/           |            |
# |    ep_len_mean     | 89.2       |
# |    ep_rew_mean     | -186.90257 |
# | time/              |            |
# |    fps             | 1087       |
# |    iterations      | 1          |
# |    time_elapsed    | 9          |
# |    total_timesteps | 10000      |
# -----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.3        |
# |    ep_rew_mean          | -153.09262  |
# | time/                   |             |
# |    fps                  | 1037        |
# |    iterations           | 2           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.006031879 |
# |    clip_fraction        | 0.0268      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0081      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 763         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 1.8e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 104        |
# |    ep_rew_mean          | -155.9514  |
# | time/                   |            |
# |    fps                  | 1027       |
# |    iterations           | 3          |
# |    time_elapsed         | 29         |
# |    total_timesteps      | 30000      |
# | train/                  |            |
# |    approx_kl            | 0.00861155 |
# |    clip_fraction        | 0.0106     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.37      |
# |    explained_variance   | -0.00894   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 469        |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.00543   |
# |    value_loss           | 1.08e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -151.10602  |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 4           |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 40000       |
# | train/                  |             |
# |    approx_kl            | 0.008679249 |
# |    clip_fraction        | 0.0347      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0172     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 393         |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00477    |
# |    value_loss           | 885         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 122        |
# |    ep_rew_mean          | -165.12045 |
# | time/                   |            |
# |    fps                  | 1002       |
# |    iterations           | 5          |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 50000      |
# | train/                  |            |
# |    approx_kl            | 0.00809185 |
# |    clip_fraction        | 0.0159     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -0.0185    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 390        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00432   |
# |    value_loss           | 795        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 153         |
# |    ep_rew_mean          | -173.17719  |
# | time/                   |             |
# |    fps                  | 997         |
# |    iterations           | 6           |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.010129829 |
# |    clip_fraction        | 0.0597      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | -0.00644    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 302         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00799    |
# |    value_loss           | 889         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 149          |
# |    ep_rew_mean          | -155.08498   |
# | time/                   |              |
# |    fps                  | 995          |
# |    iterations           | 7            |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 70000        |
# | train/                  |              |
# |    approx_kl            | 0.0069204206 |
# |    clip_fraction        | 0.0424       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.00918      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 234          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00512     |
# |    value_loss           | 672          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | -141.54828  |
# | time/                   |             |
# |    fps                  | 993         |
# |    iterations           | 8           |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 80000       |
# | train/                  |             |
# |    approx_kl            | 0.006516319 |
# |    clip_fraction        | 0.0323      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | -0.000641   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 274         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 539         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 146          |
# |    ep_rew_mean          | -116.282196  |
# | time/                   |              |
# |    fps                  | 993          |
# |    iterations           | 9            |
# |    time_elapsed         | 90           |
# |    total_timesteps      | 90000        |
# | train/                  |              |
# |    approx_kl            | 0.0073695173 |
# |    clip_fraction        | 0.0514       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.00085     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 311          |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 579          |
# ------------------------------------------
# Eval num_timesteps=100000, episode_reward=-719.50 +/- 55.59
# Episode length: 833.20 +/- 76.02
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 833         |
# |    mean_reward          | -719        |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.006310463 |
# |    clip_fraction        | 0.0546      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.000802    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 265         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 482         |
# -----------------------------------------
# New best mean reward!
# -----------------------------------
# | rollout/           |            |
# |    ep_len_mean     | 174        |
# |    ep_rew_mean     | -89.597374 |
# | time/              |            |
# |    fps             | 967        |
# |    iterations      | 10         |
# |    time_elapsed    | 103        |
# |    total_timesteps | 100000     |
# -----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 213         |
# |    ep_rew_mean          | -71.60684   |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 11          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 110000      |
# | train/                  |             |
# |    approx_kl            | 0.008332717 |
# |    clip_fraction        | 0.0371      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | -0.0214     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 171         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00522    |
# |    value_loss           | 396         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 219          |
# |    ep_rew_mean          | -56.069008   |
# | time/                   |              |
# |    fps                  | 963          |
# |    iterations           | 12           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 120000       |
# | train/                  |              |
# |    approx_kl            | 0.0062030936 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.0493       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 239          |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00473     |
# |    value_loss           | 415          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 279         |
# |    ep_rew_mean          | -48.084686  |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 13          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 130000      |
# | train/                  |             |
# |    approx_kl            | 0.007716909 |
# |    clip_fraction        | 0.0445      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.0277      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 83          |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 253         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 301         |
# |    ep_rew_mean          | -33.48491   |
# | time/                   |             |
# |    fps                  | 966         |
# |    iterations           | 14          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 140000      |
# | train/                  |             |
# |    approx_kl            | 0.009078973 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.129       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 65.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00535    |
# |    value_loss           | 195         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | -37.94747   |
# | time/                   |             |
# |    fps                  | 967         |
# |    iterations           | 15          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 150000      |
# | train/                  |             |
# |    approx_kl            | 0.010508781 |
# |    clip_fraction        | 0.0848      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.105       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 98.7        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00631    |
# |    value_loss           | 235         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 410         |
# |    ep_rew_mean          | -28.03513   |
# | time/                   |             |
# |    fps                  | 968         |
# |    iterations           | 16          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.004433856 |
# |    clip_fraction        | 0.0297      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0836      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 129         |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00374    |
# |    value_loss           | 266         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 429          |
# |    ep_rew_mean          | -42.063576   |
# | time/                   |              |
# |    fps                  | 969          |
# |    iterations           | 17           |
# |    time_elapsed         | 175          |
# |    total_timesteps      | 170000       |
# | train/                  |              |
# |    approx_kl            | 0.0067568473 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.14         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.3         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00409     |
# |    value_loss           | 98.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 455         |
# |    ep_rew_mean          | -53.312218  |
# | time/                   |             |
# |    fps                  | 969         |
# |    iterations           | 18          |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 180000      |
# | train/                  |             |
# |    approx_kl            | 0.005405464 |
# |    clip_fraction        | 0.0272      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0.000135    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 177         |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00245    |
# |    value_loss           | 301         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 497         |
# |    ep_rew_mean          | -59.691116  |
# | time/                   |             |
# |    fps                  | 970         |
# |    iterations           | 19          |
# |    time_elapsed         | 195         |
# |    total_timesteps      | 190000      |
# | train/                  |             |
# |    approx_kl            | 0.008956713 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.0686      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.1        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 202         |
# -----------------------------------------
# Eval num_timesteps=200000, episode_reward=-705.82 +/- 79.42
# Episode length: 949.40 +/- 101.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 949         |
# |    mean_reward          | -706        |
# | time/                   |             |
# |    total_timesteps      | 200000      |
# | train/                  |             |
# |    approx_kl            | 0.005041953 |
# |    clip_fraction        | 0.0402      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.965      |
# |    explained_variance   | 0.0874      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 114         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 186         |
# -----------------------------------------
# New best mean reward!
# -----------------------------------
# | rollout/           |            |
# |    ep_len_mean     | 546        |
# |    ep_rew_mean     | -54.471783 |
# | time/              |            |
# |    fps             | 957        |
# |    iterations      | 20         |
# |    time_elapsed    | 208        |
# |    total_timesteps | 200000     |
# -----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 599          |
# |    ep_rew_mean          | -50.51076    |
# | time/                   |              |
# |    fps                  | 958          |
# |    iterations           | 21           |
# |    time_elapsed         | 219          |
# |    total_timesteps      | 210000       |
# | train/                  |              |
# |    approx_kl            | 0.0070253224 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.959       |
# |    explained_variance   | 0.188        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 47.4         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0048      |
# |    value_loss           | 111          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 618          |
# |    ep_rew_mean          | -51.664783   |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 22           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 220000       |
# | train/                  |              |
# |    approx_kl            | 0.0081377225 |
# |    clip_fraction        | 0.0633       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.949       |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 39.1         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00505     |
# |    value_loss           | 99           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 662          |
# |    ep_rew_mean          | -43.449345   |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 23           |
# |    time_elapsed         | 239          |
# |    total_timesteps      | 230000       |
# | train/                  |              |
# |    approx_kl            | 0.0070929527 |
# |    clip_fraction        | 0.0865       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.982       |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 35.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00596     |
# |    value_loss           | 76.7         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 726        |
# |    ep_rew_mean          | -30.987705 |
# | time/                   |            |
# |    fps                  | 962        |
# |    iterations           | 24         |
# |    time_elapsed         | 249        |
# |    total_timesteps      | 240000     |
# | train/                  |            |
# |    approx_kl            | 0.00735267 |
# |    clip_fraction        | 0.0554     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.931     |
# |    explained_variance   | 0.194      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17         |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.0043    |
# |    value_loss           | 43.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 771         |
# |    ep_rew_mean          | -22.568666  |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 25          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 250000      |
# | train/                  |             |
# |    approx_kl            | 0.008019512 |
# |    clip_fraction        | 0.0774      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.978      |
# |    explained_variance   | 0.278       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.9        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00574    |
# |    value_loss           | 36          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 810          |
# |    ep_rew_mean          | -14.451655   |
# | time/                   |              |
# |    fps                  | 964          |
# |    iterations           | 26           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 260000       |
# | train/                  |              |
# |    approx_kl            | 0.0062550427 |
# |    clip_fraction        | 0.0683       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.984       |
# |    explained_variance   | 0.332        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00531     |
# |    value_loss           | 27.3         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 863       |
# |    ep_rew_mean          | -5.080904 |
# | time/                   |           |
# |    fps                  | 964       |
# |    iterations           | 27        |
# |    time_elapsed         | 279       |
# |    total_timesteps      | 270000    |
# | train/                  |           |
# |    approx_kl            | 0.0090377 |
# |    clip_fraction        | 0.0861    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.986    |
# |    explained_variance   | 0.358     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 14.9      |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -0.00686  |
# |    value_loss           | 23.7      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 905          |
# |    ep_rew_mean          | 5.597477     |
# | time/                   |              |
# |    fps                  | 965          |
# |    iterations           | 28           |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 280000       |
# | train/                  |              |
# |    approx_kl            | 0.0053642397 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.965       |
# |    explained_variance   | 0.358        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00423     |
# |    value_loss           | 40.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 930         |
# |    ep_rew_mean          | 15.632113   |
# | time/                   |             |
# |    fps                  | 965         |
# |    iterations           | 29          |
# |    time_elapsed         | 300         |
# |    total_timesteps      | 290000      |
# | train/                  |             |
# |    approx_kl            | 0.004136141 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.951      |
# |    explained_variance   | 0.315       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00328    |
# |    value_loss           | 53.4        |
# -----------------------------------------
# Eval num_timesteps=300000, episode_reward=-40.42 +/- 27.44
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | -40.4        |
# | time/                   |              |
# |    total_timesteps      | 300000       |
# | train/                  |              |
# |    approx_kl            | 0.0054885675 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.899       |
# |    explained_variance   | 0.589        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00268     |
# |    value_loss           | 20.7         |
# ------------------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 946       |
# |    ep_rew_mean     | 23.521269 |
# | time/              |           |
# |    fps             | 956       |
# |    iterations      | 30        |
# |    time_elapsed    | 313       |
# |    total_timesteps | 300000    |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 35.168793    |
# | time/                   |              |
# |    fps                  | 957          |
# |    iterations           | 31           |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 310000       |
# | train/                  |              |
# |    approx_kl            | 0.0092965085 |
# |    clip_fraction        | 0.0785       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.884       |
# |    explained_variance   | 0.449        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 46.4         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00368     |
# |    value_loss           | 43.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | 52.122875   |
# | time/                   |             |
# |    fps                  | 958         |
# |    iterations           | 32          |
# |    time_elapsed         | 333         |
# |    total_timesteps      | 320000      |
# | train/                  |             |
# |    approx_kl            | 0.011973043 |
# |    clip_fraction        | 0.0567      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.303       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.3        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00449    |
# |    value_loss           | 69.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 910          |
# |    ep_rew_mean          | 65.75733     |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 33           |
# |    time_elapsed         | 343          |
# |    total_timesteps      | 330000       |
# | train/                  |              |
# |    approx_kl            | 0.0037926405 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.0863       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61.8         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00224     |
# |    value_loss           | 132          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | 82.28861     |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 34           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 340000       |
# | train/                  |              |
# |    approx_kl            | 0.0043393294 |
# |    clip_fraction        | 0.0103       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.0844       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 102          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 140          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 844         |
# |    ep_rew_mean          | 100.89404   |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 35          |
# |    time_elapsed         | 363         |
# |    total_timesteps      | 350000      |
# | train/                  |             |
# |    approx_kl            | 0.005367645 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.769      |
# |    explained_variance   | 0.0707      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 51.9        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00196    |
# |    value_loss           | 117         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 824         |
# |    ep_rew_mean          | 105.0091    |
# | time/                   |             |
# |    fps                  | 962         |
# |    iterations           | 36          |
# |    time_elapsed         | 374         |
# |    total_timesteps      | 360000      |
# | train/                  |             |
# |    approx_kl            | 0.005358756 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.828      |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 50.2        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 130         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 806         |
# |    ep_rew_mean          | 109.51209   |
# | time/                   |             |
# |    fps                  | 963         |
# |    iterations           | 37          |
# |    time_elapsed         | 384         |
# |    total_timesteps      | 370000      |
# | train/                  |             |
# |    approx_kl            | 0.004217838 |
# |    clip_fraction        | 0.0255      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.856      |
# |    explained_variance   | 0.134       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 46.7        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00187    |
# |    value_loss           | 130         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 792          |
# |    ep_rew_mean          | 110.457214   |
# | time/                   |              |
# |    fps                  | 964          |
# |    iterations           | 38           |
# |    time_elapsed         | 393          |
# |    total_timesteps      | 380000       |
# | train/                  |              |
# |    approx_kl            | 0.0022716094 |
# |    clip_fraction        | 0.0108       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.875       |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.2         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00123     |
# |    value_loss           | 120          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 784          |
# |    ep_rew_mean          | 107.95561    |
# | time/                   |              |
# |    fps                  | 965          |
# |    iterations           | 39           |
# |    time_elapsed         | 404          |
# |    total_timesteps      | 390000       |
# | train/                  |              |
# |    approx_kl            | 0.0038946439 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.853       |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.2         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 122          |
# ------------------------------------------
# Eval num_timesteps=400000, episode_reward=-80.06 +/- 21.72
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | -80.1       |
# | time/                   |             |
# |    total_timesteps      | 400000      |
# | train/                  |             |
# |    approx_kl            | 0.004577064 |
# |    clip_fraction        | 0.03        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.251       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.4        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00178    |
# |    value_loss           | 98.3        |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 804       |
# |    ep_rew_mean     | 100.88578 |
# | time/              |           |
# |    fps             | 958       |
# |    iterations      | 40        |
# |    time_elapsed    | 417       |
# |    total_timesteps | 400000    |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 812          |
# |    ep_rew_mean          | 95.46432     |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 41           |
# |    time_elapsed         | 427          |
# |    total_timesteps      | 410000       |
# | train/                  |              |
# |    approx_kl            | 0.0039599207 |
# |    clip_fraction        | 0.0303       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.844       |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.7         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00153     |
# |    value_loss           | 81.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 831         |
# |    ep_rew_mean          | 86.6009     |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 42          |
# |    time_elapsed         | 437         |
# |    total_timesteps      | 420000      |
# | train/                  |             |
# |    approx_kl            | 0.006026098 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.839      |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.6        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 94.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 856         |
# |    ep_rew_mean          | 78.14768    |
# | time/                   |             |
# |    fps                  | 961         |
# |    iterations           | 43          |
# |    time_elapsed         | 447         |
# |    total_timesteps      | 430000      |
# | train/                  |             |
# |    approx_kl            | 0.004173349 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.837      |
# |    explained_variance   | 0.399       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.5        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00166    |
# |    value_loss           | 62.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | 64.617485    |
# | time/                   |              |
# |    fps                  | 962          |
# |    iterations           | 44           |
# |    time_elapsed         | 457          |
# |    total_timesteps      | 440000       |
# | train/                  |              |
# |    approx_kl            | 0.0054610423 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.978       |
# |    explained_variance   | 0.51         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.2         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 37.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | 58.540035    |
# | time/                   |              |
# |    fps                  | 963          |
# |    iterations           | 45           |
# |    time_elapsed         | 467          |
# |    total_timesteps      | 450000       |
# | train/                  |              |
# |    approx_kl            | 0.0045166286 |
# |    clip_fraction        | 0.0432       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.906       |
# |    explained_variance   | 0.464        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.6         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00211     |
# |    value_loss           | 43.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 914         |
# |    ep_rew_mean          | 52.37593    |
# | time/                   |             |
# |    fps                  | 964         |
# |    iterations           | 46          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 460000      |
# | train/                  |             |
# |    approx_kl            | 0.004393502 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.968      |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00201    |
# |    value_loss           | 44.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 927          |
# |    ep_rew_mean          | 42.38911     |
# | time/                   |              |
# |    fps                  | 964          |
# |    iterations           | 47           |
# |    time_elapsed         | 487          |
# |    total_timesteps      | 470000       |
# | train/                  |              |
# |    approx_kl            | 0.0034363517 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.79         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000885    |
# |    value_loss           | 53           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 931          |
# |    ep_rew_mean          | 39.95365     |
# | time/                   |              |
# |    fps                  | 965          |
# |    iterations           | 48           |
# |    time_elapsed         | 497          |
# |    total_timesteps      | 480000       |
# | train/                  |              |
# |    approx_kl            | 0.0034218323 |
# |    clip_fraction        | 0.0316       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.898       |
# |    explained_variance   | 0.333        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 89.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 938          |
# |    ep_rew_mean          | 31.578777    |
# | time/                   |              |
# |    fps                  | 966          |
# |    iterations           | 49           |
# |    time_elapsed         | 506          |
# |    total_timesteps      | 490000       |
# | train/                  |              |
# |    approx_kl            | 0.0044444995 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.864       |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.6         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 96.5         |
# ------------------------------------------
# Eval num_timesteps=500000, episode_reward=-77.03 +/- 45.28
# Episode length: 998.20 +/- 3.60
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 998          |
# |    mean_reward          | -77          |
# | time/                   |              |
# |    total_timesteps      | 500000       |
# | train/                  |              |
# |    approx_kl            | 0.0021644172 |
# |    clip_fraction        | 0.0137       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.463        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.000724    |
# |    value_loss           | 55.4         |
# ------------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 938       |
# |    ep_rew_mean     | 33.022346 |
# | time/              |           |
# |    fps             | 958       |
# |    iterations      | 50        |
# |    time_elapsed    | 521       |
# |    total_timesteps | 500000    |
# ----------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | 32.37987     |
# | time/                   |              |
# |    fps                  | 954          |
# |    iterations           | 51           |
# |    time_elapsed         | 534          |
# |    total_timesteps      | 510000       |
# | train/                  |              |
# |    approx_kl            | 0.0031191672 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.873       |
# |    explained_variance   | 0.492        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.4         |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000817    |
# |    value_loss           | 71.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | 24.066748   |
# | time/                   |             |
# |    fps                  | 955         |
# |    iterations           | 52          |
# |    time_elapsed         | 544         |
# |    total_timesteps      | 520000      |
# | train/                  |             |
# |    approx_kl            | 0.003800068 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.845      |
# |    explained_variance   | 0.357       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.9        |
# |    n_updates            | 510         |
# ...
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 470         |
# |    ep_rew_mean          | 220.67528   |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 564         |
# |    time_elapsed         | 5876        |
# |    total_timesteps      | 5640000     |
# | train/                  |             |
# |    approx_kl            | 0.002560693 |
# |    clip_fraction        | 0.0282      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.343      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.72        |
# |    n_updates            | 5630        |
# |    policy_gradient_loss | -0.000823   |
# |    value_loss           | 13          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 464         |
# |    ep_rew_mean          | 227.06577   |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 565         |
# |    time_elapsed         | 5886        |
# |    total_timesteps      | 5650000     |
# | train/                  |             |
# |    approx_kl            | 0.003861557 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.351      |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 5640        |
# |    policy_gradient_loss | -0.00114    |
# |    value_loss           | 7.3         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 477          |
# |    ep_rew_mean          | 225.78871    |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 566          |
# |    time_elapsed         | 5896         |
# |    total_timesteps      | 5660000      |
# | train/                  |              |
# |    approx_kl            | 0.0019012982 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.338       |
# |    explained_variance   | 0.968        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.8          |
# |    n_updates            | 5650         |
# |    policy_gradient_loss | -9.5e-05     |
# |    value_loss           | 10.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 479          |
# |    ep_rew_mean          | 223.96646    |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 567          |
# |    time_elapsed         | 5906         |
# |    total_timesteps      | 5670000      |
# | train/                  |              |
# |    approx_kl            | 0.0024002485 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.369       |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77         |
# |    n_updates            | 5660         |
# |    policy_gradient_loss | -0.000681    |
# |    value_loss           | 8.02         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 481          |
# |    ep_rew_mean          | 222.75812    |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 568          |
# |    time_elapsed         | 5916         |
# |    total_timesteps      | 5680000      |
# | train/                  |              |
# |    approx_kl            | 0.0020853204 |
# |    clip_fraction        | 0.0171       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.37        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.55         |
# |    n_updates            | 5670         |
# |    policy_gradient_loss | -0.000749    |
# |    value_loss           | 24.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 480          |
# |    ep_rew_mean          | 223.75746    |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 569          |
# |    time_elapsed         | 5926         |
# |    total_timesteps      | 5690000      |
# | train/                  |              |
# |    approx_kl            | 0.0023638683 |
# |    clip_fraction        | 0.0226       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.341       |
# |    explained_variance   | 0.963        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.84         |
# |    n_updates            | 5680         |
# |    policy_gradient_loss | -0.000591    |
# |    value_loss           | 13.7         |
# ------------------------------------------
# Eval num_timesteps=5700000, episode_reward=246.92 +/- 16.44
# Episode length: 415.60 +/- 20.03
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 416         |
# |    mean_reward          | 247         |
# | time/                   |             |
# |    total_timesteps      | 5700000     |
# | train/                  |             |
# |    approx_kl            | 0.004233687 |
# |    clip_fraction        | 0.0337      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.38        |
# |    n_updates            | 5690        |
# |    policy_gradient_loss | -0.000156   |
# |    value_loss           | 14.3        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 487      |
# |    ep_rew_mean     | 222.0816 |
# | time/              |          |
# |    fps             | 959      |
# |    iterations      | 570      |
# |    time_elapsed    | 5938     |
# |    total_timesteps | 5700000  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 462          |
# |    ep_rew_mean          | 226.654      |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 571          |
# |    time_elapsed         | 5948         |
# |    total_timesteps      | 5710000      |
# | train/                  |              |
# |    approx_kl            | 0.0013599171 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.332       |
# |    explained_variance   | 0.949        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.9         |
# |    n_updates            | 5700         |
# |    policy_gradient_loss | -0.000378    |
# |    value_loss           | 18.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 448          |
# |    ep_rew_mean          | 232.07883    |
# | time/                   |              |
# |    fps                  | 959          |
# |    iterations           | 572          |
# |    time_elapsed         | 5958         |
# |    total_timesteps      | 5720000      |
# | train/                  |              |
# |    approx_kl            | 0.0022622389 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.331       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.8          |
# |    n_updates            | 5710         |
# |    policy_gradient_loss | 2.8e-05      |
# |    value_loss           | 7.48         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 449         |
# |    ep_rew_mean          | 234.7772    |
# | time/                   |             |
# |    fps                  | 959         |
# |    iterations           | 573         |
# |    time_elapsed         | 5968        |
# |    total_timesteps      | 5730000     |
# | train/                  |             |
# |    approx_kl            | 0.002838484 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.322      |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.36        |
# |    n_updates            | 5720        |
# |    policy_gradient_loss | -0.000613   |
# |    value_loss           | 7.96        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 455          |
# |    ep_rew_mean          | 232.23705    |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 574          |
# |    time_elapsed         | 5979         |
# |    total_timesteps      | 5740000      |
# | train/                  |              |
# |    approx_kl            | 0.0027492042 |
# |    clip_fraction        | 0.0459       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.359       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.33         |
# |    n_updates            | 5730         |
# |    policy_gradient_loss | -0.00135     |
# |    value_loss           | 13.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 466          |
# |    ep_rew_mean          | 229.7903     |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 575          |
# |    time_elapsed         | 5989         |
# |    total_timesteps      | 5750000      |
# | train/                  |              |
# |    approx_kl            | 0.0035828552 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.361       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.08         |
# |    n_updates            | 5740         |
# |    policy_gradient_loss | -0.000758    |
# |    value_loss           | 10.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 466          |
# |    ep_rew_mean          | 230.07869    |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 576          |
# |    time_elapsed         | 5999         |
# |    total_timesteps      | 5760000      |
# | train/                  |              |
# |    approx_kl            | 0.0031000045 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.38        |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.96         |
# |    n_updates            | 5750         |
# |    policy_gradient_loss | -0.00166     |
# |    value_loss           | 10.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 485          |
# |    ep_rew_mean          | 226.29214    |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 577          |
# |    time_elapsed         | 6009         |
# |    total_timesteps      | 5770000      |
# | train/                  |              |
# |    approx_kl            | 0.0019106986 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.322       |
# |    explained_variance   | 0.951        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.23         |
# |    n_updates            | 5760         |
# |    policy_gradient_loss | -0.000679    |
# |    value_loss           | 16.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 483          |
# |    ep_rew_mean          | 226.13774    |
# | time/                   |              |
# |    fps                  | 960          |
# |    iterations           | 578          |
# |    time_elapsed         | 6019         |
# |    total_timesteps      | 5780000      |
# | train/                  |              |
# |    approx_kl            | 0.0019122141 |
# |    clip_fraction        | 0.021        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.355       |
# |    explained_variance   | 0.95         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.9          |
# |    n_updates            | 5770         |
# |    policy_gradient_loss | -0.001       |
# |    value_loss           | 15.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 460         |
# |    ep_rew_mean          | 231.9569    |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 579         |
# |    time_elapsed         | 6029        |
# |    total_timesteps      | 5790000     |
# | train/                  |             |
# |    approx_kl            | 0.003397309 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.36       |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.21        |
# |    n_updates            | 5780        |
# |    policy_gradient_loss | -0.000901   |
# |    value_loss           | 17.9        |
# -----------------------------------------
# Eval num_timesteps=5800000, episode_reward=257.43 +/- 13.43
# Episode length: 514.80 +/- 192.89
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 515          |
# |    mean_reward          | 257          |
# | time/                   |              |
# |    total_timesteps      | 5800000      |
# | train/                  |              |
# |    approx_kl            | 0.0021459714 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.316       |
# |    explained_variance   | 0.965        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.9          |
# |    n_updates            | 5790         |
# |    policy_gradient_loss | -0.000509    |
# |    value_loss           | 12.2         |
# ------------------------------------------
# New best mean reward!
# Stopping training because the mean reward 257.43  is above the threshold 250.0
# Moviepy - Building video /kaggle/working/outputs/lunarlander_ppo/video/rl-video-episode-0.mp4.
# Moviepy - Writing video /kaggle/working/outputs/lunarlander_ppo/video/rl-video-episode-0.mp4
# Moviepy - Done !
# Moviepy - video ready /kaggle/working/outputs/lunarlander_ppo/video/rl-video-episode-0.mp4
